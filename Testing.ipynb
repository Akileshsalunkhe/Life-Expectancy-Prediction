# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df=pd.read_csv("Life Expectancy Data.csv")

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
sns.countplot(x='Status',data=df)

# %%
sns.scatterplot(x='percentage expenditure',y='GDP',data=df,estimator=np.std)

# %%
sns.scatterplot(x='GDP',y=' thinness  1-19 years',data=df,estimator=np.std)

# %%
sns.scatterplot(x='Life expectancy ',y=' BMI ',data=df,estimator=np.std)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="viridis")

# %%
df.isnull().sum(axis=0)
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="viridis")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   object
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   float64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   float64
#  9   Measles                          1649 non-null   int64
#  10   BMI                             1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
# ...

# %%
developing = pd.get_dummies(df['Status'],drop_first=True)

# %%
df=pd.concat([df,developing],axis=1)

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
plt.figure(figsize=(18, 12))
sns.heatmap(df.corr(),center=0,annot=True)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'Developing'],
#       dtype='object')

# %%
df.drop('Year',axis=1,inplace=True)

# %%
df.drop('Measles ',axis=1,inplace=True)

# %%
df.drop('Population',axis=1,inplace=True)

# %%
df.drop('under-five deaths ',axis=1,inplace=True)

# %%
df.drop('infant deaths',axis=1,inplace=True)

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                                  Life expectancy   Adult Mortality   Alcohol  \
# Life expectancy                          1.000000        -0.702523  0.402718
# Adult Mortality                         -0.702523         1.000000 -0.175535
# Alcohol                                  0.402718        -0.175535  1.000000
# percentage expenditure                   0.409631        -0.237610  0.417047
# Hepatitis B                              0.199935        -0.105225  0.109889
#  BMI                                     0.542042        -0.351542  0.353396
# Polio                                    0.327294        -0.199853  0.240315
# Total expenditure                        0.174718        -0.085227  0.214885
# Diphtheria                               0.341331        -0.191429  0.242951
#  HIV/AIDS                               -0.592236         0.550691 -0.027113
# GDP                                      0.441322        -0.255035  0.443433
# ...

# %%
plt.figure(figsize=(15, 12))
sns.heatmap(df.corr(),center=0,annot=True)

# %%
X = df[['Adult Mortality', 'Alcohol', 'percentage expenditure', 'Hepatitis B', ' BMI ', 'Polio', 'Total expenditure',
       'Diphtheria ', ' HIV/AIDS', 'GDP',
       ' thinness  1-19 years', ' thinness 5-9 years',
       'Income composition of resources', 'Schooling']].astype(float)

# %%
y = df[ "Life expectancy " ].astype(float)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.intercept_
# Out:
# 51.39612210632383

# %%
lm.coef_
# Out:
# array([-1.75908993e-02, -9.87232523e-02,  3.80101847e-04, -4.86075916e-03,
#         2.97530880e-02,  1.34092862e-02,  9.49251112e-02,  1.71102325e-02,
#        -4.21363365e-01,  3.62711823e-06, -1.11715575e-02, -6.28891294e-02,
#         1.08909735e+01,  9.44395983e-01])

# %%
X_train.columns
# Out:
# Index(['Adult Mortality', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        ' BMI ', 'Polio', 'Total expenditure', 'Diphtheria ', ' HIV/AIDS',
#        'GDP', ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_,X.columns,columns=['Coeff'])

# %%
cdf
# Out:
#                                      Coeff
# Adult Mortality                  -0.017591
# Alcohol                          -0.098723
# percentage expenditure            0.000380
# Hepatitis B                      -0.004861
#  BMI                              0.029753
# Polio                             0.013409
# Total expenditure                 0.094925
# Diphtheria                        0.017110
#  HIV/AIDS                        -0.421363
# GDP                               0.000004
#  thinness  1-19 years            -0.011172
#  thinness 5-9 years              -0.062889
# Income composition of resources  10.890974
# Schooling                         0.944396

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot(y_test-predictions)

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,predictions)
# Out:
# 2.7877785673549385

# %%
metrics.mean_squared_error(y_test,predictions)
# Out:
# 13.19906350417085

# %%
np.sqrt(metrics.mean_squared_error(y_test,predictions))
# Out:
# 3.633051541634229
